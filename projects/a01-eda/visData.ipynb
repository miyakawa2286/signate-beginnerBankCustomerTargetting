# %%
import os
print(os.getcwd())
import sys

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

sys.path.append('../../my_modules/')
from utils import read_dataset
# Out:
# /workspace/projects/a01-eda

# %%
train,test,sub = read_dataset('../../data/')
# Out:
# Memory usage of dataframe is 3.72 MB
# Memory usage after optimization is: 0.62 MB
# Decreased by 83.3%
# Memory usage of dataframe is 2.34 MB
# Memory usage after optimization is: 0.40 MB
# Decreased by 83.0%
# Memory usage of dataframe is 0.28 MB
# Memory usage after optimization is: 0.05 MB
# Decreased by 81.2%

# %%
train.head()
# Out:
#    id  age           job  marital  education default  balance housing loan  \
# 0   0   31      services  married  secondary      no    12294     yes   no
# 1   1   29  entrepreneur   single   tertiary      no    43027      no   no
# 2   2   35    management  married   tertiary      no    12252     yes   no
# 3   3   31    technician  married  secondary      no    99121     yes  yes
# 4   4   48    unemployed  married    primary      no    42005     yes   no
#
#      contact  day month  duration  campaign  pdays  previous poutcome  y
# 0   cellular   21   nov       101         3    498         0    other  0
# 1   cellular   22   aug       158         2    702         0  unknown  1
# 2   cellular   11   nov       351         1    826         0  failure  0
# 3    unknown   16   may       658         2    120         0  failure  0
# 4  telephone    3   apr       177         1    273         0  unknown  0

# %%
drop_cols = ['id']
features = [c for c in test.columns if not c in drop_cols]
features_and_t = features + ['y']

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27100 entries, 0 to 27099
# Data columns (total 18 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   id         27100 non-null  int16
#  1   age        27100 non-null  int8
#  2   job        27100 non-null  category
#  3   marital    27100 non-null  category
#  4   education  27100 non-null  category
#  5   default    27100 non-null  category
#  6   balance    27100 non-null  int32
#  7   housing    27100 non-null  category
#  8   loan       27100 non-null  category
#  9   contact    27100 non-null  category
#  10  day        27100 non-null  int8
#  11  month      27100 non-null  category
#  12  duration   27100 non-null  int16
#  13  campaign   27100 non-null  int8
#  14  pdays      27100 non-null  int16
#  15  previous   27100 non-null  int8
#  16  poutcome   27100 non-null  category
#  17  y          27100 non-null  int8
# dtypes: category(9), int16(3), int32(1), int8(5)
# ...

# %% [markdown]
# # Visualization

# %%
sns.pairplot(train.loc[::5,features_and_t])
